# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn
import scipy as sp 
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import os
# import sys; sys.path.append('/home/mfc/Dropbox/spring2016/dataMining/projects/project2/')
root_dir = '/home/mfc/Dropbox/spring2016/dataMining/projects/project2/'
os.chdir(root_dir)
import numpy as np

from kcenter import *


# %matplotlib inline

# %%
data = pd.read_csv('data/wdbc.csv')
data.head(5)
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471   ...     25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  \
# 0  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 1  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 2  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 3  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
# 4  0.08089   ...     15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355
#
#    0.2654  0.4601   0.1189
# 0  0.1860  0.2750  0.08902
# 1  0.2430  0.3613  0.08758
# 2  0.2575  0.6638  0.17300
# 3  0.1625  0.2364  0.07678
# 4  0.1741  0.3985  0.12440
#
# [5 rows x 32 columns]

# %%
X = data.iloc[:,2:].values


# normalizing the data
X = scale(X)

# %%
pca = PCA(n_components=2)

X_2 = pca.fit_transform(X)

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_2[:,0], X_2[:,1], c=data.iloc[:,1], s=50, alpha=0.6)
plt.xlabel('PCA_1')
plt.ylabel('PCA_2')

# %%
c,r,label = kcenter(X_2, 2)


ax = plt.figure(figsize=(15,15))
plt.scatter(X_2[:,0], X_2[:,1], c=label, 
            cmap=plt.cm.gnuplot, s=50, alpha=0.7)


plt.scatter(c[0][0],c[0][1], s=400)
plt.scatter(c[1][0],c[1][1], s=400)

# plt.xlim((-12,12))
# plt.ylim((-12,12))

circle1 = plt.Circle((c[0][0],c[0][1]),
                     r[0], color='b',
                     fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle1)

circle2 = plt.Circle((c[1][0],c[1][1]),
                     r[1], color='g',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle2)


plt.xlabel('PCA_1')
plt.ylabel('PCA_2')

# %%
c,r,label = kcenter(X_2, 3)


ax = plt.figure(figsize=(15,15))
plt.scatter(X_2[:,0], X_2[:,1], c=label, 
            cmap=plt.cm.gnuplot, s=50, alpha=0.7)


plt.scatter(c[0][0],c[0][1], s=400)
plt.scatter(c[1][0],c[1][1], s=400)
plt.scatter(c[2][0],c[2][1], s=400)


# plt.xlim((-12,12))
# plt.ylim((-12,12))

circle1 = plt.Circle((c[0][0],c[0][1]),
                     r[0], color='b',
                     fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle1)

circle2 = plt.Circle((c[1][0],c[1][1]),
                     r[1], color='g',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle2)

circle3 = plt.Circle((c[2][0],c[2][1]),
                     r[2], color='r',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle3)

plt.xlabel('PCA_1')
plt.ylabel('PCA_2')

# %%
c,r,label = kcenter(X_2, 4)


ax = plt.figure(figsize=(15,15))
plt.scatter(X_2[:,0], X_2[:,1], c=label, 
            cmap=plt.cm.gnuplot, s=50, alpha=0.7)


plt.scatter(c[0][0],c[0][1], s=400)
plt.scatter(c[1][0],c[1][1], s=400)
plt.scatter(c[2][0],c[2][1], s=400)
plt.scatter(c[3][0],c[3][1], s=400)

# plt.xlim((-12,12))
# plt.ylim((-12,12))

circle1 = plt.Circle((c[0][0],c[0][1]),
                     r[0], color='b',
                     fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle1)

circle2 = plt.Circle((c[1][0],c[1][1]),
                     r[1], color='g',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle2)

circle3 = plt.Circle((c[2][0],c[2][1]),
                     r[2], color='r',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle3)

circle4 = plt.Circle((c[3][0],c[3][1]),
                     r[2], color='r',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle4)

plt.xlabel('PCA_1')
plt.ylabel('PCA_2')

# %%
c,r,label = kcenter(X_2, 5)


ax = plt.figure(figsize=(15,15))
plt.scatter(X_2[:,0], X_2[:,1], c=label, 
            cmap=plt.cm.gnuplot, s=50, alpha=0.7)


plt.scatter(c[0][0],c[0][1], s=400)
plt.scatter(c[1][0],c[1][1], s=400)
plt.scatter(c[2][0],c[2][1], s=400)
plt.scatter(c[3][0],c[3][1], s=400)
plt.scatter(c[4][0],c[3][1], s=400)

# plt.xlim((-12,12))
# plt.ylim((-12,12))

circle1 = plt.Circle((c[0][0],c[0][1]),
                     r[0], color='b',
                     fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle1)

circle2 = plt.Circle((c[1][0],c[1][1]),
                     r[1], color='g',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle2)

circle3 = plt.Circle((c[2][0],c[2][1]),
                     r[2], color='r',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle3)

circle4 = plt.Circle((c[3][0],c[3][1]),
                     r[2], color='r',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle4)

circle5 = plt.Circle((c[4][0],c[4][1]),
                     r[2], color='r',
                    fill=False, clip_on=True, alpha=1)
ax.gca().add_artist(circle5)

plt.xlabel('PCA_1')
plt.ylabel('PCA_2')
